# %%
import os
import numpy as np

print(os.getcwd())
npz_path = os.path.join(os.getcwd(), 'validation_scribbles/2D_CT_0001.npz')
print(os.path.exists(npz_path))
# Out:
# /Users/sophiastiles/Custom/Research
# True

# %%
data = np.load(npz_path)
img = data['imgs']
scribbles = data['scribbles']

print(img.shape)
print(scribbles.shape)

print(type(img))
print(type(scribbles))
# Out:
# (512, 512, 3)
# (512, 512)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt

# CT scan, so in grayscale even though 3 channels
plt.imshow(img)
plt.show()
plt.imshow(scribbles)
