# %%
import os
import numpy as np
from pathlib import Path

folder_path = os.path.join(os.getcwd(), 'Test_npz/')
print(os.path.exists(folder_path))
# Out:
# True

# %%
files = os.listdir(folder_path)
print(len(files))
# Out:
# 191

# %%
file_names = os.listdir(folder_path)

# print("Inferior" in file_names)

# # Print the list of file names
for f in sorted(file_names):
    if "CT_Teeth" in f:
        print(f)
# Out:
# 2D_CT_Teeth_1007_0043_boxes.npz
# 2D_CT_Teeth_1027_0038_boxes.npz
# 2D_CT_Teeth_test1_0128_boxes.npz
# 2D_CT_Teeth_test26_0202_boxes.npz
# 2D_CT_Teeth_test3_0162_boxes.npz
# 2D_CT_Teeth_test5_0186_boxes.npz
